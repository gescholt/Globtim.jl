# %% [markdown]
# ## Holder Table Function

# %%
using Pkg
Pkg.activate("../../.")
using Globtim
using DynamicPolynomials, DataFrames
using ProgressLogging
# Out:
#   Activating project at `~/Globtim.jl`

# %%
# Constants and Parameters
const n, a, b = 2, 10, 1
const scale_factor = a / b   # Scaling factor appears in `main_computation`, maybe it should be a parameter.
const delta, alpha = 0.5, 1 / 10  # Sampling parameters
const tol_l2 = 3e-4            # Define the tolerance for the L2-norm
f = HolderTable # Objective function
# Out:
# HolderTable (generic function with 1 method)

# %%
d = 18 # Initial Degree 
SMPL = 40 # Number of samples
center = [0.0, 0.0]
TR = test_input(n, center, (alpha, delta), tol_l2, (0.0, 0.0), scale_factor, 1.0, f)
pol_cheb = Constructor(TR, d, GN=SMPL, basis=:chebyshev)
pol_lege = Constructor(TR, d, GN=SMPL, basis=:legendre);
# Out:
# current L2-norm: 0.03248275406196476
# Number of samples: 40
# current L2-norm: 0.02243641155105562
# Number of samples: 40

# %%
@polyvar(x[1:n]) # Define polynomial ring
# Out:
# (Variable{DynamicPolynomials.Commutative{DynamicPolynomials.CreationOrder}, Graded{LexOrder}}[x₁, x₂],)

# %%
real_pts_cheb = solve_polynomial_system(x, n, d, pol_cheb.coeffs; basis=:chebyshev, bigint=true)
real_pts_lege = solve_polynomial_system(x, n, d, pol_lege.coeffs; basis=:legendre, bigint=true)
# Usage example:
df_cheb = process_critical_points(real_pts_cheb, f, scale_factor)
df_lege = process_critical_points(real_pts_lege, f, scale_factor)
# Out:
# Tracking 289 paths...   1%|▎                            |  ETA: 0:11:41
#
#
#
# Tracking 289 paths...  27%|███████▉                     |  ETA: 0:00:14
#
#
#
# Tracking 289 paths...  55%|████████████████             |  ETA: 0:00:04
#
#
#
# Tracking 289 paths...  82%|███████████████████████▋     |  ETA: 0:00:01
#
#
#
# Tracking 289 paths... 100%|█████████████████████████████| Time: 0:00:05
#   # paths tracked:                  289
#   # non-singular solutions (real):  289 (181)
#   # singular endpoints (real):      0 (0)
#   # total solutions (real):         289 (181)
# Tracking 289 paths...   1%|▎                            |  ETA: 0:13:52
#
#
#
# Tracking 289 paths...   1%|▍                            |  ETA: 0:07:19
#
#
#
# Tracking 289 paths...   2%|▌                            |  ETA: 0:06:19
#
#
#
# Tracking 289 paths...   2%|▋                            |  ETA: 0:05:25
#
#
#
# Tracking 289 paths...   3%|▊                            |  ETA: 0:04:15
#
#
#
# Tracking 289 paths...   3%|█                            |  ETA: 0:03:30
#
#
#
# Tracking 289 paths...   4%|█▎                           |  ETA: 0:03:01
#
#
#
# Tracking 289 paths...   4%|█▎                           |  ETA: 0:02:51
#
#
#
# Tracking 289 paths...   5%|█▍                           |  ETA: 0:02:50
#
#
#
# Tracking 289 paths...   5%|█▌                           |  ETA: 0:02:42
#
#
#
# Tracking 289 paths...   6%|█▊                           |  ETA: 0:02:28
#
#
#
# Tracking 289 paths...   6%|█▊                           |  ETA: 0:02:23
#
#
#
# Tracking 289 paths...   7%|█▉                           |  ETA: 0:02:18
#
#
#
# Tracking 289 paths...   7%|██▏                          |  ETA: 0:02:09
#
#
#
# Tracking 289 paths...   8%|██▎                          |  ETA: 0:02:08
#
#
#
# Tracking 289 paths...   8%|██▎                          |  ETA: 0:02:05
#
#
#
# Tracking 289 paths...   8%|██▍                          |  ETA: 0:02:02
#
#
#
# Tracking 289 paths...   9%|██▋                          |  ETA: 0:01:55
#
#
#
# Tracking 289 paths...  10%|██▊                          |  ETA: 0:01:50
#
#
#
# Tracking 289 paths...  10%|██▉                          |  ETA: 0:01:47
#
#
#
# Tracking 289 paths...  10%|███                          |  ETA: 0:01:46
#
#
#
# Tracking 289 paths...  11%|███▏                         |  ETA: 0:01:46
#
#
#
# Tracking 289 paths...  11%|███▎                         |  ETA: 0:01:45
#
#
#
# Tracking 289 paths...  11%|███▎                         |  ETA: 0:01:45
#
#
#
# Tracking 289 paths...  12%|███▌                         |  ETA: 0:01:42
#
#
#
# Tracking 289 paths...  12%|███▋                         |  ETA: 0:01:40
#
#
#
# Tracking 289 paths...  13%|███▊                         |  ETA: 0:01:39
#
#
#
# Tracking 289 paths...  13%|███▉                         |  ETA: 0:01:37
#
#
#
# Tracking 289 paths...  13%|███▉                         |  ETA: 0:01:37
#
#
#
# Tracking 289 paths...  14%|████                         |  ETA: 0:01:36
#
#
#
# Tracking 289 paths...  14%|████▏                        |  ETA: 0:01:35
#
#
#
# Tracking 289 paths...  15%|████▎                        |  ETA: 0:01:33
#
#
#
# Tracking 289 paths...  15%|████▍                        |  ETA: 0:01:32
#
#
#
# Tracking 289 paths...  16%|████▌                        |  ETA: 0:01:29
#
#
#
# Tracking 289 paths...  16%|████▋                        |  ETA: 0:01:28
#
#
#
# Tracking 289 paths...  16%|████▊                        |  ETA: 0:01:28
#
#
#
# Tracking 289 paths...  17%|████▉                        |  ETA: 0:01:27
#
#
#
# Tracking 289 paths...  17%|████▉                        |  ETA: 0:01:27
#
#
#
# Tracking 289 paths...  17%|█████                        |  ETA: 0:01:26
#
#
#
# Tracking 289 paths...  18%|█████▏                       |  ETA: 0:01:25
#
#
#
# Tracking 289 paths...  18%|█████▎                       |  ETA: 0:01:24
#
#
#
# Tracking 289 paths...  18%|█████▍                       |  ETA: 0:01:24
#
#
#
# Tracking 289 paths...  19%|█████▍                       |  ETA: 0:01:23
#
#
#
# Tracking 289 paths...  19%|█████▌                       |  ETA: 0:01:22
#
#
#
# Tracking 289 paths...  19%|█████▋                       |  ETA: 0:01:22
#
#
#
# Tracking 289 paths...  20%|█████▊                       |  ETA: 0:01:22
#
#
#
# Tracking 289 paths...  20%|█████▉                       |  ETA: 0:01:21
#
#
#
# Tracking 289 paths...  20%|█████▉                       |  ETA: 0:01:20
#
#
#
# Tracking 289 paths...  21%|██████                       |  ETA: 0:01:20
#
#
#
# Tracking 289 paths...  21%|██████▏                      |  ETA: 0:01:19
#
#
#
# Tracking 289 paths...  21%|██████▎                      |  ETA: 0:01:18
#
#
#
# Tracking 289 paths...  22%|██████▍                      |  ETA: 0:01:17
#
#
#
# Tracking 289 paths...  22%|██████▌                      |  ETA: 0:01:17
#
#
#
# Tracking 289 paths...  23%|██████▋                      |  ETA: 0:01:16
#
#
#
# Tracking 289 paths...  24%|██████▉                      |  ETA: 0:01:14
#
#
#
# Tracking 289 paths...  24%|██████▉                      |  ETA: 0:01:14
#
#
#
# Tracking 289 paths...  24%|███████                      |  ETA: 0:01:13
#
#
#
# Tracking 289 paths...  25%|███████▎                     |  ETA: 0:01:12
#
#
#
# Tracking 289 paths...  25%|███████▍                     |  ETA: 0:01:12
#
#
#
# Tracking 289 paths...  26%|███████▍                     |  ETA: 0:01:11
#
#
#
# Tracking 289 paths...  26%|███████▋                     |  ETA: 0:01:10
#
#
#
# Tracking 289 paths...  27%|███████▊                     |  ETA: 0:01:09
#
#
#
# Tracking 289 paths...  27%|███████▉                     |  ETA: 0:01:08
#
#
#
# Tracking 289 paths...  27%|███████▉                     |  ETA: 0:01:08
#
#
#
# Tracking 289 paths...  28%|████████▏                    |  ETA: 0:01:07
#
#
#
# Tracking 289 paths...  28%|████████▎                    |  ETA: 0:01:06
#
#
#
# Tracking 289 paths...  29%|████████▍                    |  ETA: 0:01:05
#
#
#
# Tracking 289 paths...  30%|████████▋                    |  ETA: 0:01:04
#
#
#
# Tracking 289 paths...  30%|████████▊                    |  ETA: 0:01:03
#
#
#
# Tracking 289 paths...  31%|████████▉                    |  ETA: 0:01:02
#
#
#
# Tracking 289 paths...  31%|█████████                    |  ETA: 0:01:02
#
#
#
# Tracking 289 paths...  31%|█████████▏                   |  ETA: 0:01:02
#
#
#
# Tracking 289 paths...  32%|█████████▍                   |  ETA: 0:01:00
#
#
#
# Tracking 289 paths...  33%|█████████▍                   |  ETA: 0:01:00
#
#
#
# Tracking 289 paths...  33%|█████████▌                   |  ETA: 0:00:59
#
#
#
# Tracking 289 paths...  33%|█████████▋                   |  ETA: 0:00:59
#
#
#
# Tracking 289 paths...  34%|█████████▉                   |  ETA: 0:00:58
#
#
#
# Tracking 289 paths...  34%|█████████▉                   |  ETA: 0:00:58
#
#
#
# Tracking 289 paths...  35%|██████████                   |  ETA: 0:00:57
#
#
#
# Tracking 289 paths...  35%|██████████▎                  |  ETA: 0:00:56
#
#
#
# Tracking 289 paths...  36%|██████████▍                  |  ETA: 0:00:56
#
#
#
# Tracking 289 paths...  36%|██████████▍                  |  ETA: 0:00:56
#
#
#
# Tracking 289 paths...  36%|██████████▌                  |  ETA: 0:00:55
#
#
#
# Tracking 289 paths...  37%|██████████▋                  |  ETA: 0:00:55
#
#
#
# Tracking 289 paths...  37%|██████████▊                  |  ETA: 0:00:55
#
#
#
# Tracking 289 paths...  37%|██████████▉                  |  ETA: 0:00:55
#
#
#
# Tracking 289 paths...  38%|███████████                  |  ETA: 0:00:54
#
#
#
# Tracking 289 paths...  38%|███████████                  |  ETA: 0:00:54
#
#
#
# Tracking 289 paths...  39%|███████████▎                 |  ETA: 0:00:53
#
#
#
# Tracking 289 paths...  39%|███████████▍                 |  ETA: 0:00:53
#
#
#
# Tracking 289 paths...  39%|███████████▌                 |  ETA: 0:00:52
#
#
#
# Tracking 289 paths...  40%|███████████▌                 |  ETA: 0:00:52
#
#
#
# Tracking 289 paths...  40%|███████████▋                 |  ETA: 0:00:52
#
#
#
# Tracking 289 paths...  40%|███████████▊                 |  ETA: 0:00:51
#
#
#
# Tracking 289 paths...  41%|███████████▉                 |  ETA: 0:00:51
#
#
#
# Tracking 289 paths...  41%|████████████                 |  ETA: 0:00:51
#
#
#
# Tracking 289 paths...  42%|████████████                 |  ETA: 0:00:51
#
#
#
# Tracking 289 paths...  42%|████████████▏                |  ETA: 0:00:50
#
#
#
# Tracking 289 paths...  42%|████████████▎                |  ETA: 0:00:50
#
#
#
# Tracking 289 paths...  43%|████████████▍                |  ETA: 0:00:50
#
#
#
# Tracking 289 paths...  43%|████████████▌                |  ETA: 0:00:50
#
#
#
# Tracking 289 paths...  43%|████████████▌                |  ETA: 0:00:49
#
#
#
# Tracking 289 paths...  44%|████████████▋                |  ETA: 0:00:49
#
#
#
# Tracking 289 paths...  44%|████████████▊                |  ETA: 0:00:48
#
#
#
# Tracking 289 paths...  45%|█████████████                |  ETA: 0:00:48
#
#
#
# Tracking 289 paths...  45%|█████████████                |  ETA: 0:00:47
#
#
#
# Tracking 289 paths...  45%|█████████████▏               |  ETA: 0:00:47
#
#
#
# Tracking 289 paths...  46%|█████████████▎               |  ETA: 0:00:47
#
#
#
# Tracking 289 paths...  46%|█████████████▍               |  ETA: 0:00:46
#
#
#
# Tracking 289 paths...  46%|█████████████▌               |  ETA: 0:00:46
#
#
#
# Tracking 289 paths...  47%|█████████████▌               |  ETA: 0:00:46
#
#
#
# Tracking 289 paths...  47%|█████████████▋               |  ETA: 0:00:45
#
#
#
# Tracking 289 paths...  47%|█████████████▊               |  ETA: 0:00:45
#
#
#
# Tracking 289 paths...  48%|█████████████▉               |  ETA: 0:00:45
#
#
#
# Tracking 289 paths...  48%|██████████████               |  ETA: 0:00:44
#
#
#
# Tracking 289 paths...  48%|██████████████               |  ETA: 0:00:44
#
#
#
# Tracking 289 paths...  49%|██████████████▏              |  ETA: 0:00:44
#
#
#
# Tracking 289 paths...  49%|██████████████▎              |  ETA: 0:00:44
#
#
#
# Tracking 289 paths...  49%|██████████████▍              |  ETA: 0:00:43
#
#
#
# Tracking 289 paths...  50%|██████████████▌              |  ETA: 0:00:43
#
#
#
# Tracking 289 paths...  51%|██████████████▋              |  ETA: 0:00:42
#
#
#
# Tracking 289 paths...  51%|██████████████▉              |  ETA: 0:00:41
#
#
#
# Tracking 289 paths...  52%|███████████████              |  ETA: 0:00:41
#
#
#
# Tracking 289 paths...  52%|███████████████              |  ETA: 0:00:41
#
#
#
# Tracking 289 paths...  52%|███████████████▏             |  ETA: 0:00:41
#
#
#
# Tracking 289 paths...  53%|███████████████▎             |  ETA: 0:00:40
#
#
#
# Tracking 289 paths...  53%|███████████████▌             |  ETA: 0:00:40
#
#
#
# Tracking 289 paths...  54%|███████████████▋             |  ETA: 0:00:39
#
#
#
# Tracking 289 paths...  54%|███████████████▊             |  ETA: 0:00:39
#
#
#
# Tracking 289 paths...  55%|███████████████▉             |  ETA: 0:00:38
#
#
#
# Tracking 289 paths...  55%|████████████████             |  ETA: 0:00:38
#
#
#
# Tracking 289 paths...  55%|████████████████             |  ETA: 0:00:38
#
#
#
# Tracking 289 paths...  56%|████████████████▎            |  ETA: 0:00:37
#
#
#
# Tracking 289 paths...  57%|████████████████▌            |  ETA: 0:00:36
#
#
#
# Tracking 289 paths...  57%|████████████████▌            |  ETA: 0:00:36
#
#
#
# Tracking 289 paths...  57%|████████████████▋            |  ETA: 0:00:36
#
#
#
# Tracking 289 paths...  58%|████████████████▊            |  ETA: 0:00:36
#
#
#
# Tracking 289 paths...  58%|████████████████▉            |  ETA: 0:00:35
#
#
#
# Tracking 289 paths...  58%|█████████████████            |  ETA: 0:00:35
#
#
#
# Tracking 289 paths...  59%|█████████████████            |  ETA: 0:00:35
#
#
#
# Tracking 289 paths...  59%|█████████████████▏           |  ETA: 0:00:34
#
#
#
# Tracking 289 paths...  60%|█████████████████▎           |  ETA: 0:00:34
#
#
#
# Tracking 289 paths...  60%|█████████████████▍           |  ETA: 0:00:34
#
#
#
# Tracking 289 paths...  60%|█████████████████▌           |  ETA: 0:00:33
#
#
#
# Tracking 289 paths...  61%|█████████████████▌           |  ETA: 0:00:33
#
#
#
# Tracking 289 paths...  61%|█████████████████▋           |  ETA: 0:00:33
#
#
#
# Tracking 289 paths...  61%|█████████████████▊           |  ETA: 0:00:33
#
#
#
# Tracking 289 paths...  62%|█████████████████▉           |  ETA: 0:00:32
#
#
#
# Tracking 289 paths...  62%|██████████████████           |  ETA: 0:00:32
#
#
#
# Tracking 289 paths...  63%|██████████████████▏          |  ETA: 0:00:31
#
#
#
# Tracking 289 paths...  63%|██████████████████▎          |  ETA: 0:00:31
#
#
#
# Tracking 289 paths...  63%|██████████████████▍          |  ETA: 0:00:31
#
#
#
# Tracking 289 paths...  64%|██████████████████▌          |  ETA: 0:00:30
#
#
#
# Tracking 289 paths...  64%|██████████████████▋          |  ETA: 0:00:30
#
#
#
# Tracking 289 paths...  64%|██████████████████▋          |  ETA: 0:00:30
#
#
#
# Tracking 289 paths...  65%|██████████████████▊          |  ETA: 0:00:30
#
#
#
# Tracking 289 paths...  65%|██████████████████▉          |  ETA: 0:00:30
#
#
#
# Tracking 289 paths...  65%|███████████████████          |  ETA: 0:00:29
#
#
#
# Tracking 289 paths...  66%|███████████████████▏         |  ETA: 0:00:29
#
#
#
# Tracking 289 paths...  66%|███████████████████▏         |  ETA: 0:00:29
#
#
#
# Tracking 289 paths...  66%|███████████████████▎         |  ETA: 0:00:29
#
#
#
# Tracking 289 paths...  67%|███████████████████▍         |  ETA: 0:00:28
#
#
#
# Tracking 289 paths...  67%|███████████████████▋         |  ETA: 0:00:28
#
#
#
# Tracking 289 paths...  68%|███████████████████▋         |  ETA: 0:00:27
#
#
#
# Tracking 289 paths...  69%|███████████████████▉         |  ETA: 0:00:27
#
#
#
# Tracking 289 paths...  69%|████████████████████         |  ETA: 0:00:27
#
#
#
# Tracking 289 paths...  69%|████████████████████▏        |  ETA: 0:00:26
#
#
#
# Tracking 289 paths...  70%|████████████████████▏        |  ETA: 0:00:26
#
#
#
# Tracking 289 paths...  70%|████████████████████▎        |  ETA: 0:00:26
#
#
#
# Tracking 289 paths...  70%|████████████████████▍        |  ETA: 0:00:25
#
#
#
# Tracking 289 paths...  71%|████████████████████▌        |  ETA: 0:00:25
#
#
#
# Tracking 289 paths...  71%|████████████████████▋        |  ETA: 0:00:25
#
#
#
# Tracking 289 paths...  71%|████████████████████▋        |  ETA: 0:00:24
#
#
#
# Tracking 289 paths...  72%|████████████████████▉        |  ETA: 0:00:24
#
#
#
# Tracking 289 paths...  72%|█████████████████████        |  ETA: 0:00:24
#
#
#
# Tracking 289 paths...  73%|█████████████████████▏       |  ETA: 0:00:23
#
#
#
# Tracking 289 paths...  73%|█████████████████████▎       |  ETA: 0:00:23
#
#
#
# Tracking 289 paths...  74%|█████████████████████▍       |  ETA: 0:00:22
#
#
#
# Tracking 289 paths...  74%|█████████████████████▌       |  ETA: 0:00:22
#
#
#
# Tracking 289 paths...  75%|█████████████████████▋       |  ETA: 0:00:21
#
#
#
# Tracking 289 paths...  75%|█████████████████████▉       |  ETA: 0:00:21
#
#
#
# Tracking 289 paths...  76%|██████████████████████       |  ETA: 0:00:20
#
#
#
# Tracking 289 paths...  76%|██████████████████████▏      |  ETA: 0:00:20
#
#
#
# Tracking 289 paths...  77%|██████████████████████▎      |  ETA: 0:00:19
#
#
#
# Tracking 289 paths...  78%|██████████████████████▌      |  ETA: 0:00:19
#
#
#
# Tracking 289 paths...  78%|██████████████████████▋      |  ETA: 0:00:18
#
#
#
# Tracking 289 paths...  79%|██████████████████████▊      |  ETA: 0:00:18
#
#
#
# Tracking 289 paths...  79%|███████████████████████      |  ETA: 0:00:17
#
#
#
# Tracking 289 paths...  80%|███████████████████████▏     |  ETA: 0:00:17
#
#
#
# Tracking 289 paths...  80%|███████████████████████▎     |  ETA: 0:00:16
#
#
#
# Tracking 289 paths...  81%|███████████████████████▌     |  ETA: 0:00:16
#
#
#
# Tracking 289 paths...  81%|███████████████████████▋     |  ETA: 0:00:16
#
#
#
# Tracking 289 paths...  82%|███████████████████████▊     |  ETA: 0:00:15
#
#
#
# Tracking 289 paths...  83%|████████████████████████     |  ETA: 0:00:14
#
#
#
# Tracking 289 paths...  83%|████████████████████████▏    |  ETA: 0:00:14
#
#
#
# Tracking 289 paths...  84%|████████████████████████▎    |  ETA: 0:00:13
#
#
#
# Tracking 289 paths...  84%|████████████████████████▍    |  ETA: 0:00:13
#
#
#
# Tracking 289 paths...  84%|████████████████████████▌    |  ETA: 0:00:13
#
#
#
# Tracking 289 paths...  85%|████████████████████████▋    |  ETA: 0:00:12
#
#
#
# Tracking 289 paths...  85%|████████████████████████▊    |  ETA: 0:00:12
#
#
#
# Tracking 289 paths...  86%|████████████████████████▉    |  ETA: 0:00:12
#
#
#
# Tracking 289 paths...  86%|█████████████████████████    |  ETA: 0:00:11
#
#
#
# Tracking 289 paths...  87%|█████████████████████████▏   |  ETA: 0:00:11
#
#
#
# Tracking 289 paths...  87%|█████████████████████████▎   |  ETA: 0:00:11
#
#
#
# Tracking 289 paths...  88%|█████████████████████████▍   |  ETA: 0:00:10
#
#
#
# Tracking 289 paths...  89%|█████████████████████████▊   |  ETA: 0:00:09
#
#
#
# Tracking 289 paths...  89%|█████████████████████████▉   |  ETA: 0:00:09
#
#
#
# Tracking 289 paths...  90%|██████████████████████████   |  ETA: 0:00:09
#
#
#
# Tracking 289 paths...  90%|██████████████████████████▏  |  ETA: 0:00:08
#
#
#
# Tracking 289 paths...  90%|██████████████████████████▎  |  ETA: 0:00:08
#
#
#
# Tracking 289 paths...  91%|██████████████████████████▎  |  ETA: 0:00:08
#
#
#
# Tracking 289 paths...  91%|██████████████████████████▍  |  ETA: 0:00:07
#
#
#
# Tracking 289 paths...  92%|██████████████████████████▋  |  ETA: 0:00:07
#
#
#
# Tracking 289 paths...  92%|██████████████████████████▊  |  ETA: 0:00:07
#
#
#
# Tracking 289 paths...  92%|██████████████████████████▊  |  ETA: 0:00:06
#
#
#
# Tracking 289 paths...  93%|██████████████████████████▉  |  ETA: 0:00:06
#
#
#
# Tracking 289 paths...  93%|███████████████████████████  |  ETA: 0:00:06
#
#
#
# Tracking 289 paths...  93%|███████████████████████████▏ |  ETA: 0:00:05
#
#
#
# Tracking 289 paths...  94%|███████████████████████████▎ |  ETA: 0:00:05
#
#
#
# Tracking 289 paths...  94%|███████████████████████████▎ |  ETA: 0:00:05
#
#
#
# Tracking 289 paths...  94%|███████████████████████████▍ |  ETA: 0:00:05
#
#
#
# Tracking 289 paths...  95%|███████████████████████████▌ |  ETA: 0:00:04
#
#
#
# Tracking 289 paths...  95%|███████████████████████████▋ |  ETA: 0:00:04
#
#
#
# Tracking 289 paths...  96%|███████████████████████████▊ |  ETA: 0:00:04
#
#
#
# Tracking 289 paths...  96%|███████████████████████████▊ |  ETA: 0:00:03
#
#
#
# Tracking 289 paths...  96%|███████████████████████████▉ |  ETA: 0:00:03
#
#
#
# Tracking 289 paths...  97%|████████████████████████████ |  ETA: 0:00:03
#
#
#
# Tracking 289 paths...  97%|████████████████████████████▏|  ETA: 0:00:03
#
#
#
# Tracking 289 paths...  98%|████████████████████████████▎|  ETA: 0:00:02
#
#
#
# Tracking 289 paths...  98%|████████████████████████████▍|  ETA: 0:00:02
#
#
#
# Tracking 289 paths...  98%|████████████████████████████▌|  ETA: 0:00:01
#
#
#
# Tracking 289 paths...  99%|████████████████████████████▋|  ETA: 0:00:01
#
#
#
# Tracking 289 paths...  99%|████████████████████████████▊|  ETA: 0:00:01
#
#
#
# Tracking 289 paths...  99%|████████████████████████████▊|  ETA: 0:00:01
#
#
#
# Tracking 289 paths...  99%|████████████████████████████▉|  ETA: 0:00:00
#
#
#
# Tracking 289 paths... 100%|█████████████████████████████| Time: 0:01:23
#   # paths tracked:                  289
#   # non-singular solutions (real):  289 (197)
#   # singular endpoints (real):      0 (0)
#   # total solutions (real):         289 (197)
# 193×3 DataFrame
#  Row │ x             y        z
#      │ Float64       Float64  Float64
# ─────┼──────────────────────────────────────
#    1 │  9.56062      9.95535   -3.4775
#    2 │  6.36225      9.74765   -1.12027
#    3 │  3.08136      9.8346    -0.540102
#    4 │  2.71112e-13  9.82686   -2.0952e-12
#    5 │ -3.08136      9.8346    -0.540102
#    6 │ -6.36225      9.74765   -1.12027
#    7 │ -8.10344      9.91092  -18.5493
#    8 │ -4.8841       9.84946  -10.9313
#   ⋮  │      ⋮           ⋮           ⋮
#  187 │ -6.30203      6.43764   -0.120497
#  188 │ -7.97731      6.54266   -9.41574
#  189 │ -5.019        6.48746   -4.67438
#  190 │ -1.69291      6.42761   -2.99758
#  191 │  1.69524      7.67277   -0.802441
#  192 │  4.9063       7.74811   -0.706741
#  193 │  8.00124      7.79414   -0.761821
#                             178 rows omitted

# %%
using GLMakie

# Extract coordinates and function values
# Change the coordinates to uniform grid
coords = pol_cheb.scale_factor * pol_lege.grid
z_coords = pol_lege.z

if size(coords)[2] == 2  # Plot if the dimensions are 2
    fig = Figure(size=(800, 600))
    ax = Axis3(fig[1, 1], title="Holder Table Function",
        xlabel="X-axis", ylabel="Y-axis", zlabel="Z-axis")

    # Scale the domain
    scale_factor = pol_cheb.scale_factor  # Using the scale factor from your polynomial

    # Define threshold for switching between scatter and surface
    point_threshold = 1000  # Adjust this value based on your needs
    sample_fraction = 0.2   # Fraction of points to use if exceeding threshold

    if length(z_coords) > point_threshold
        # Create a regular grid for surface plotting
        x_unique = sort(unique(coords[:, 1]))
        y_unique = sort(unique(coords[:, 2]))

        # Determine grid dimensions
        nx = length(x_unique)
        ny = length(y_unique)

        # Reshape data into a grid
        z_grid = reshape(z_coords, nx, ny)

        # Create surface plot with scaled domain
        surface!(ax, scale_factor .* x_unique, scale_factor .* y_unique, z_grid,
            colormap=:viridis,
            transparency=true,
            alpha=0.8)

        # Sample a fraction of points for scatter overlay
        n_points = length(z_coords)
        sample_indices = rand(1:n_points, Int(floor(n_points * sample_fraction)))

        # Plot sampled scatter points with scaled domain
        scatter!(ax, scale_factor .* coords[sample_indices, 1],
            scale_factor .* coords[sample_indices, 2],
            z_coords[sample_indices],
            markersize=2,
            color=:black,
            label="Sampled Data Points")
    else
        # Original scatter plot for smaller datasets with scaled domain
        scatter!(ax, scale_factor .* coords[:, 1],
            scale_factor .* coords[:, 2],
            z_coords,
            markersize=2,
            color=:black,
            label="Sampled Data Core")

        scatter!(ax, scale_factor .* coords[:, 1],
            scale_factor .* coords[:, 2],
            z_coords,
            markersize=4,
            color=z_coords,
            colormap=:viridis,
            label="Sampled Data Halo")
    end

    # Plot the critical points with scaled domain
    scatter!(ax, scale_factor .* df_cheb.x,
        scale_factor .* df_cheb.y,
        df_cheb.z,
        markersize=10,
        color=:orange,
        label="Chebyshev approximant critical points")

    scatter!(ax, scale_factor .* df_lege.x,
        scale_factor .* df_lege.y,
        df_lege.z,
        markersize=10,
        color=:yellow,
        label="Legendre approximant critical points")

    display(fig)
end
# Out:
# GLMakie.Screen(...)
